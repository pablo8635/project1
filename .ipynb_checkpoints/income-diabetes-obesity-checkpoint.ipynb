# %%
#Import Modules
import pandas as pd

# %%
#Read annual csv files and create DataFrames 
annual_files = ['2015-Annual.csv', '2016-Annual.csv', '2017-Annual.csv','2018-Annual.csv', '2019-Annual.csv']

dfs = []
for file in annual_files:
    df = pd.read_csv(file, index_col=None, header=0)
    dfs.append(df)

big_frame = pd.concat(dfs, ignore_index=True)
big_frame
# Out:
#         Edition  Report Type        Measure Name     State Name  Rank  Value  \
# 0          2015  2015 Annual       Air Pollution        Alabama  34.0    9.5
# 1          2015  2015 Annual       Air Pollution         Alaska   4.0    6.0
# 2          2015  2015 Annual       Air Pollution        Arizona  37.0    9.7
# 3          2015  2015 Annual       Air Pollution       Arkansas  37.0    9.7
# 4          2015  2015 Annual       Air Pollution     California  50.0   12.5
# ...         ...          ...                 ...            ...   ...    ...
# 181517     2019  2019 Annual  Water Fluoridation        Vermont  40.0   56.3
# 181518     2019  2019 Annual  Water Fluoridation     Washington  33.0   63.9
# 181519     2019  2019 Annual  Water Fluoridation      Wisconsin  16.0   88.9
# 181520     2019  2019 Annual  Water Fluoridation  West Virginia  14.0   90.5
# 181521     2019  2019 Annual  Water Fluoridation        Wyoming  39.0   57.1
#
#         Score  Lower CI  Upper CI  \
# ...

# %%
#Read other csv files and create DataFrames
other_files = ['Median Household Income.csv', 'Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv']

li = []
for file in other_files:
    df = pd.read_csv(file, index_col=None, header=0)
    li.append(df)
    
df_median_income = pd.DataFrame(li[0])
df_obesity = pd.DataFrame(li[1])

df_median_income
# Out:
#              State            2018           2018.1            2017  \
# 0            State  Median\nincome  Standard\nerror  Median\nincome
# 1    United States          63,179              420          61,372
# 2          Alabama          49,936            2,423          51,113
# 3           Alaska          68,734            3,390          72,231
# 4          Arizona          62,283            2,291          61,125
# 5         Arkansas          49,781            2,108          48,829
# 6       California          70,489            1,233          69,759
# 7         Colorado          73,034            3,562          74,172
# 8      Connecticut          72,812            5,119          72,780
# 9         Delaware          65,012            3,599          62,318
# 10            D.C.          85,750            2,659          83,382
# 11         Florida          54,644            1,887          53,681
# 12         Georgia          55,821            2,032          57,016
# ...

# %%
#IGNORAR 
from datapackage import Package
data_url = 'https://datahub.io/machine-learning/diabetes/datapackage.json'

# to load Data Package into storage
package = datapackage.Package(data_url)

# to load only tabular data
resources = package.resources
for resource in resources:
    if resource.tabular:
        data = pd.read_csv(resource.descriptor['path'])
        print (data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e9b449d6177f> in <module>
#       2
#       3 # to load Data Package into storage
# ----> 4 package = datapackage.Package(data_url)
#       5
#       6 # to load only tabular data
#
# NameError: name 'datapackage' is not defined

# %%
#Statistical analysis

# %%
#Create maps
